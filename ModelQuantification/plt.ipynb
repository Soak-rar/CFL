# %%
import numpy as np
import torch
import Model
from torchvision import datasets, transforms
import Args
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
import pandas
import threading
import multiprocessing
import data.ff
from HCFedAvg import FileProcess
from HCFedAvg.DataGenerater import *
from torchsummary import summary
import math
import ast

# %%
header_no = FileProcess.read_row_with_file_name(0, "QuantResult")
header_quant = FileProcess.read_row_with_file_name(1, "QuantResult")
dis_list_1 = ast.literal_eval(header_no["acc_list"])
dis_list_2 = ast.literal_eval(header_quant["acc_list"])

fig = plt.figure(figsize=(24, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(range(len(dis_list_1)), dis_list_1,  color='r', label='FedAvg_WithoutQuant')
ax1.plot(range(len(dis_list_2)), dis_list_2,  color='b', label='FedAvg_WithQuant')
ax1.legend(loc= 'center', prop={'size': 14}, bbox_to_anchor=(0.55, 0.5))
ax1.set_xlabel('Train Round', fontsize=12)
ax1.set_ylabel('Accuracy', fontsize=12)

plt.show()
